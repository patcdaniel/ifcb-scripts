# %% [markdown]
# ## Getting Recent SC Wharf IFCB Data
#
# Data from the auto-class can be accessed remotely from requests.
#
# First, we need to the PID for the most recent bin of data

# %%
import requests, json
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt

# %%
now = "T".join(str(dt.datetime.now()).split(" ")).split('.')[0]
url = "http://128.114.25.154:8888/IFCB104/api/feed/nearest/" + now
response = requests.get(url).json()
pid = response['pid']
print(pid)
# Out:
# http://128.114.25.154:8888/IFCB104/D20210701T201527_IFCB104

# %%
autoclass_url = pid+"_class_scores.csv"
df_autoclass = pd.read_csv(autoclass_url) # These are percentage of counts
df_autoclass.head()
# Out:
#                               pid  Akashiwo  Alexandrium_singlet  \
# 0  D20210701T201527_IFCB104_00001       0.0                 0.00
# 1  D20210701T201527_IFCB104_00002       0.0                 0.00
# 2  D20210701T201527_IFCB104_00003       0.0                 0.00
# 3  D20210701T201527_IFCB104_00004       0.0                 0.00
# 4  D20210701T201527_IFCB104_00005       0.0                 0.01
#
#    Amy_Gony_Protoc  Asterionellopsis  Centric  Ceratium  Chaetoceros  \
# 0             0.08              0.01     0.02      0.00         0.09
# 1             0.00              0.01     0.00      0.00         0.02
# 2             0.00              0.00     0.38      0.00         0.00
# 3             0.00              0.00     0.48      0.00         0.03
# 4             0.00              0.09     0.00      0.02         0.67
#
#    Cochlodinium  Cryptophyte  ...  Peridinium  Lingulodinium  Pennate  \
# 0          0.02         0.00  ...         0.0            0.0     0.06
# 1          0.00         0.92  ...         0.0            0.0     0.00
# 2          0.00         0.00  ...         0.0            0.0     0.07
# 3          0.00         0.00  ...         0.0            0.0     0.05
# 4          0.00         0.00  ...         0.0            0.0     0.00
#
#    Prorocentrum  Pseudo-nitzschia  Scrip_Het  Skeletonema  Thalassionema  \
# 0           0.0              0.00       0.03          NaN            NaN
# 1           0.0              0.00       0.02          NaN            NaN
# 2           0.0              0.00       0.02          NaN            NaN
# 3           0.0              0.00       0.11          NaN            NaN
# 4           0.0              0.02       0.01          NaN            NaN
#
#    Thalassiosira  unclassified
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
#
# [5 rows x 29 columns]

# %%
totals = df_autoclass.apply(lambda x: x == df_autoclass.max(axis=1)).sum()
totals = totals.reset_index(name='counts')
totals = totals.rename(columns={'index':'class'})
totals = totals.sort_values(['counts']).reset_index(drop=True)
totals = totals.drop(totals[totals['class'].isin(["pid", "Skeletonema",	"Thalassionema", "Thalassiosira", "unclassified"])].index)
totals.head()
# Out:
#               class  counts
# 3  Pseudo-nitzschia       0
# 4      Prorocentrum       0
# 5     Lingulodinium       0
# 6         Guin_Dact       0
# 7        Dinophysis       0

# %%
ax = sns.barplot(x="class", y="counts", data=totals,  palette="Blues_d",edgecolor=".2");
plt.xticks(rotation=90, ha='center');
plt.title(pid +"\nTotal Detections: {}".format(df_autoclass.shape[0]))
# Out:
# Text(0.5, 1.0, 'http://128.114.25.154:8888/IFCB104/D20210629T161913_IFCB104\nTotal Detections: 1719')
